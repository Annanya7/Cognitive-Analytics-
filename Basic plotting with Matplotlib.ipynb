# %% [markdown]
# We can show matplotlib figures directly in the notebook by using the %matplotlib notbook and %matplotlib inline magic commands.
#
# %matplotlib notebook provides an interactive environment

# %%
# %matplotlib notebook

# %%
import matplotlib as mpl
mpl.get_backend()
# Out:
# 'nbAgg'

# %%
import matplotlib.pyplot as plt
plt.plot?

# %%
plt.plot(3,2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(3,2, '.')

# %%
from matplotlib.backends.backend_agg import FigureCanvasAgg
from matplotlib.figure import Figure

fig = Figure()
canvas = FigureCanvasAgg(fig)

ax = fig.add_subplot(111)
ax.plot(3,2, '.')
canvas.print_png('test.png')

# %%
# %%html
# <img src = 'test.png' />
# Out:
# <img src = 'test.png' />

# %%
plt.figure()
plt.plot(3, 2, 'o')
ax = plt.gca()
ax.axis([0,6,0,10])
# Out:
# <img src="data:image/png;base64,..." width="640">
# [0, 6, 0, 10]

# %%
plt.figure()
plt.plot(1.5, 1.5, 'o')
plt.plot(2, 2, 'o')
plt.plot(2.5, 2.5, 'o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax = plt.gca()
ax.get_children()
# Out:
# [<matplotlib.lines.Line2D at 0x1cbec06d7c8>,
#  <matplotlib.lines.Line2D at 0x1cbec0726c8>,
#  <matplotlib.lines.Line2D at 0x1cbec039a88>,
#  <matplotlib.spines.Spine at 0x1cbec061808>,
#  <matplotlib.spines.Spine at 0x1cbec07a8c8>,
#  <matplotlib.spines.Spine at 0x1cbec07a408>,
#  <matplotlib.spines.Spine at 0x1cbec07aa08>,
#  <matplotlib.axis.XAxis at 0x1cbec061548>,
#  <matplotlib.axis.YAxis at 0x1cbec075508>,
#  Text(0.5, 1, ''),
#  Text(0.0, 1, ''),
#  Text(1.0, 1, ''),
#  <matplotlib.patches.Rectangle at 0x1cbec456188>]
